# %%
# Data Structure
questions_Dict = {
    1 : "\033[1mQ1: I am the life of the party.\033[0m",
    2 : "\033[1mQ2: I feel little concern for others.\033[0m",
    3 : "\033[1mQ3: I am always prepared.\033[0m",
    4 : "\033[1mQ4: I get stressed out easily.\033[0m",
    5 : "\033[1mQ5: I have a rich vocabulary.\033[0m",
    6 : "\033[1mQ6: I don't talk a lot.\033[0m",
    7 : "\033[1mQ7: I am interested in people.\033[0m",
    8 : "\033[1mQ8: I leave my belongings around.\033[0m",
    9 : "\033[1mQ9: I am relaxed most of the time.\033[0m",
    10  : "\033[1mQ10: I have difficulty understanding abstract ideas.\033[0m",
    11  : "\033[1mQ11: I feel comfortable around people.\033[0m",
    12  : "\033[1mQ12: I insult people,\033[0m",
    13  : "\033[1mQ13: I pay attention to details.\033[0m",
    14  : "\033[1mQ14: I worry about things.\033[0m",
    15  : "\033[1mQ15: I have a vivid imagination.\033[0m",
    16  : "\033[1mQ16: I keep in the background.\033[0m",
    17  : "\033[1mQ17: I sympathize with other's feelings.\033[0m",
    18  : "\033[1mQ18: I make a mess of things.\033[0m",
    19  : "\033[1mQ19: I seldom feel blue.\033[0m",
    20  : "\033[1mQ20: I am not interested in abstract ideas.\033[0m",
    21  : "\033[1mQ21: I start conversations.\033[0m",
    22  : "\033[1mQ22: I am not interested in other people's problems.\033[0m",
    23  : "\033[1mQ23: I get chores done right away.\033[0m",
    24  : "\033[1mQ24: I am easily disturbed.\033[0m",
    25  : "\033[1mQ25: I have excellent ideas.\033[0m",
    26  : "\033[1mQ26: I have little to say.\033[0m",
    27  : "\033[1mQ27:I have a soft heart.\033[0m",
    28  : "\033[1mQ28: I often forget to put things back in their proper place.\033[0m",
    29  : "\033[1mQ29: I get upset easily.\033[0m",
    30  : "\033[1mQ30: I do not have a good imagination.\033[0m",
    31  : "\033[1mQ31: I talk to a lot of different people at parties.\033[0m",
    32  : "\033[1mQ32: I am not really interested in others.\033[0m",
    33  : "\033[1mQ33: I like order.\033[0m",
    34  : "\033[1mQ34: I change my mood a lot.\033[0m",
    35  : "\033[1mQ35: I am quick to understand things.\033[0m",
    36  : "\033[1mQ36: I don't like to draw attention to myself.\033[0m",
    37  : "\033[1mQ37: I take time out for others.\033[0m",
    38  : "\033[1mQ38: I shirk my duties.\033[0m",
    39  : "\033[1mQ39: I have frequent mood swings.\033[0m",
    40  : "\033[1mQ40: I use different words.\033[0m",
    41  : "\033[1mQ41: I don't mind being the center of attention.\033[0m",
    42  : "\033[1mQ42: I feel other's emotions.\033[0m",
    43  : "\033[1mQ43: I follow a schedule.\033[0m",
    44  : "\033[1mQ44: I get irritated easily.\033[0m",
    45  : "\033[1mQ45: I spend time reflecting on things.\033[0m",
    46  : "\033[1mQ46: I am quiet around strangers.\033[0m",
    47  : "\033[1mQ47: I make people feel at ease.\033[0m",
    48  : "\033[1mQ48: I am exacting in my work.\033[0m",
    49  : "\033[1mQ49: I often feel blue.\033[0m",
    50  : "\033[1mQ50: I am full of ideas.\033[0m"
}

# %%
# answer
answer = []

# result
result_list = []

# %%
 #calculate the result
 def cal(answer, result_list):
   E = 20 + answer[0] - answer[5] + answer[10] - answer[15] + answer[20] + answer[25] + answer[30] - answer[35] + answer[40] + answer[45]
   A = 14 - answer[1] + answer[6] - answer[11] + answer[16] - answer[21] + answer[26] - answer[31] + answer[36] + answer[41] + answer[46]
   C = 14 + answer[2] - answer[7] + answer[12] - answer[17] + answer[22] - answer[27] + answer[32] - answer[37] - answer[42] + answer[47]
   N = 38 - answer[3] + answer[8] - answer[13] + answer[18] - answer[23] - answer[28] - answer[33] - answer[38] - answer[43] - answer[48]
   O = 8 + answer[4] - answer[9] + answer[14] - answer[19] + answer[24] - answer[29] + answer[34] + answer[39] + answer[44] + answer[49]
   result_list.extend((E, A, C, N, O)) #merge the result of the calculation into the result_list

# %%
# Introduction

print('\033[91m\033[1m'"""Introduction \033[0m:
This is a personality test, it will help you understand why you act the way that 
you do and how your personality is structured. Please follow the instructions below, 
scoring and results will be displayed after the test.""")

while True:
  con = input("please type C to continue it!")
  if con != "C" and con != "c":
    print("Please type c again")
  else:
   print("***Please read the instructions below.***")
   break

# Instructions
print('\033[91m\033[1m' + """Instructions\033[0m:
In the test, for each statement 1-50 mark how much you agree with on the scale 1-5, as shown below.
\033[94m1=disagree
2=slightly disagree
3=neutral
4=slightly agree
5=agree\033[0m""")

# Main test
while True:
  val = input("Now, do you understand how to do the test? Yes/No")
  if val != "Yes" and val != "yes":
    print("Please read the instruction again!!")
  else:
    break
print("The test starts now!")
    
for i in range(len(questions_Dict)):
  print(questions_Dict.get(i+1)) # .get => return a value for the given key
  ans = input("1=disagree, 2=slightly disagree, 3=neutral, 4=slightly agree, 5 = agree")
  answer.append(int(ans))
  print("***You still have", len(questions_Dict) - (i+1), "questions.***")
if len(answer) > 49:
  print("\033[91m\033[1m'The end of the test!\033[0m")


# finish result_list
while True:
  result = input("Do you want to see the result? Type yes/no")
  if result !="Yes" and result != "yes":
    print("It's ok! Thanks for your time. Goodbye!")
    break
  else:
    cal(answer, result_list)

    print("\033[36m✭The score you calculate should be between zero and forty.✭\033[0m")
    print("E-->", result_list[0])
    print("A-->", result_list[1])
    print("C-->", result_list[2])
    print("N-->", result_list[3])
    print("O-->", result_list[4])
    break

# a description of each trait

while True:
  val = input("Do you want to read a description of each trait? Yes/No")
  if val != "Yes" and val != "yes":
    print("OK! Thanks for your time.")
    break
  else:
    print("""\033[1m▪︎ Extroversion(E)\033[0m is the personality trait of seeking 
  fulfillment from sources outside the self or in community. High scores tend to 
  be very social while low scores prefer to work on their projects alone.""")

    print("""\033[1m▪ Agreeableness(A)\033[0m relfects much individuals adjust their 
  behavior to suit others. High scorers are typically polit and like people. 
  Low scorers tend to tell it like it is""")

    print("""\033[1m▪︎ Conscientiousness(C)\033[0m is the personality trait of being 
  honest and hardworking. High scorers tend to follow rules and prefer clean homes.   
  Low scorers may be messy and cheat others.""")

    print("""▪\033[1m︎ Neuroticism(N)\033[0m is the personality trait of being emotional.""")

    print("""▪︎\033[1m︎ Openness to Experience(O)\033[0m is the personality trait of 
  seeking new experience and intellectual pursuits. High scores may day dream a lot. 
  Low scorers may be very down to earth.""")
    break
# Out:
# Introduction :
# This is a personality test, it will help you understand why you act the way that
# you do and how your personality is structured. Please follow the instructions below,
# scoring and results will be displayed after the test.
# please type C to continue it!c
# ***Please read the instructions below.***
# Instructions:
# In the test, for each statement 1-50 mark how much you agree with on the scale 1-5, as shown below.
# 1=disagree
# 2=slightly disagree
# 3=neutral
# 4=slightly agree
# 5=agree
# Now, do you understand how to do the test? Yes/Nono
# Please read the instruction again!!
# Now, do you understand how to do the test? Yes/Noyes
# The test starts now!
# Q1: I am the life of the party.
# 1=disagree, 2=slightly disagree, 3=neutral, 4=slightly agree, 5 = agree5
# ***You still have 49 questions.***
# Q2: I feel little concern for others.
# 1=disagree, 2=slightly disagree, 3=neutral, 4=slightly agree, 5 = agree4
# ***You still have 48 questions.***
# ...
